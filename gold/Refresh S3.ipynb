-- %%
INSERT OVERWRITE TABLE gold.fact_product_entries_ext
SELECT * FROM openfoodfactslakehouse.gold.fact_product_entries;

INSERT OVERWRITE TABLE gold.dim_brands_ext
SELECT * FROM openfoodfactslakehouse.gold.dim_brands;

INSERT OVERWRITE TABLE gold.dim_products_ext
SELECT * FROM openfoodfactslakehouse.gold.dim_products;
