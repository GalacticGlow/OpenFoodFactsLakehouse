-- %%
SELECT
  *
FROM openfoodfactslakehouse.gold.fact_product_entries
WHERE last_product_image_datetime >= "2026-04-30T14:16:01.000+00:00"

-- %%
CREATE RECIPIENT my_recipient2

-- %%
GRANT SELECT ON SHARE openfoodfacts_share TO RECIPIENT my_recipient2;
